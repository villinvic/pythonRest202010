# %% [markdown]
# # Magic Square

# %%
import numpy as np

# %%
def isMagic(square):
    pass

# %%
def makeMagic(n):
    pass

# %%
carreN = np.array([
    [ 8, 1, 6], 
    [3,5,7], 
    [4,9,2]])
isMagic(carreN)
